# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий ревьювера</h1>
#
# Айдар, привет!
#
# 🤚 Меня зовут Волкова Оля, я буду проверять твой проект. Если не против, я буду обращаться к тебе на _ТЫ_ . Если
#     предпочтительнее общение на _ВЫ_ , то обязательно напиши мне об этом в комментариях.
#
#
# ✏️ В этой тетрадке далее мои комментарии будут выделены по цветам:
#
#
# <div class="alert alert-block alert-success">
# <b>✔️ Комментарий ревьюера:</b> Зеленный блок указывает на твои удачные решения и сильные стороны работы
# </div>
#
#
#
#
# <div class="alert alert-block alert-warning">
# <b> ⚠️ Комментарий ревьюера:</b> Желтый блок указывает на то, что задание решено корректно, но какие-то вещи можно улучшить для большей эффективности работы, чистоты кода, поддержки и пр.
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b> Красный блок указывает на то, то в задании допущена ошибка, которая влияет на итоговые результаты, и без исправления которой работа не будет принята.
# </div>
#
#
#
# 📈 Не удаляй мои комментарии, так будет проще следить за динамикой.

# %% [markdown]
# **Цель проекта:**
#
# Провести анализ клиентов банка и сегментировать пользователей по количеству потребляемых продуктов, обращая внимание на отток клиентов, чтобы изменение банковских продуктов приводило к уменьшению оттока.
#
# Заказчиком проекта является отдел маркетинга, который хочет знать портрет клиентов, чтобы продвигать новые продукты и снизить отток. Проведенные ранее исследования (дашборд) устарели, поскольку изменился состав клиентов банка и старые сегменты сейчас не подходят.
#
# План работы (декомпозиция проекта)
# 1. Загрузить данные
# 2. Привести названия столбцов к змеиному регистру
# 3. Проверить данные на пропуски
# 4. Проверить данные на явные и неявные дубликаты
# 5. Перевести переменные city и gender в бинарный формат
# 6. Изучить аномалии в данных
# 7. Провести категоризацию данных по значению "score", "balance", "EST_SALARY"
# 8. Исследовать коореляцию параметров клиентов: количество продуктов, возраст, пол и т.д.
# 9. Исследовать, какие признаки влияют на количество используемых продуктов
# 10. Проверить статистические гипотезы:
# - Н0: Возраст клиентов, которые пользуются одним и двумя продуктами не отличается
# - Н1: Возраст клиентов, которые пользуются одним и двумя продуктами отличается
#
#
# - Н0: Отсутствие кредитных продуктов не влияет на отток клиентов
# - Н1: Отсутствие кредитных продуктов влияет на отток клиентов
#
# 11. Выявить взаимосвязь между оттоком и другими параметрами в датасете.
# 12. Провести сегментацию пользователей на основе данных о количестве потребляемых продуктов.
# 13. Подвести итоги о том, что влияет на отток клиентов, сформулировать рекомендации для отдела маркетинга
# 14. На основе полученных данных построить дашборд и презентацию

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b> Цель должна отвечать на вопрос "Зачем?". Задачи должны быть отделены от самой декомпозииции. Декомпозицию расписать по-подробнее. Не сформулирована вторая гипотеза
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   Убрал задачи, расписал декомпозицию подробнее, сформулировал вторую гипотезу

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера 2:</b> на каком этапе будет проведена сегментация? Изучение аномалий? Изучение самих данных по банку?
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Сегментация пользователей на основе данных о количестве потребляемых продуктов будет проведена на этапе 9.
# Изучение аномалий добавил в пункт 6.
# Изучение данных по банку это пункты 1, 3, 4, 6, 8.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера 3:</b> Сегментация и проверка гипотез - это разные этапы, не стоит их смешивать. Пункты 1,3,4,6,8 - это предаврительное изучение данных, нужно его дополнить изучением по задаче работы
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     Выделил сегментацию в отдельную задачу и добавил пункт 9.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Комментарий ревьюера 4:</b> Ок
# </div>

# %% [markdown]
# **План презентации**
# - Название проекта
# - Цели и задачи проекта
# - Краткое описание исходного датасета (кем предоставлен, какое количество данных содержит, данные за какой период)
# - Основные результаты, полученные в ходе анализа данных: распределения, в т.ч. в разрезе продуктов, портреты клиентов и их сравнение, корреляционный анализ, результаты проверки гипотез, результаты сегментации: данные по оттоку пользователей в зависимости от количества потребляемых продуктов.
# - Выводы

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b> Описание данных нужно на минимальном уровне, а вот про то, что будут содержать результаты, стоит уточнить по-подробнее
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     Добавил описание результатов

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера 2:</b> Не хватает описания сегментов
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     Добавил в пункт с результатами

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Комментарий ревьюера 3:</b> Ок
# </div>
